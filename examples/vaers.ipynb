# %%
import pandas as pd

# %%
df = pd.read_csv('VAERS/2021VAERSData.csv', encoding = "ISO-8859-1")
df_vax = pd.read_csv('VAERS/2021VAERSVAX.csv', encoding = "ISO-8859-1")
df_symp = pd.read_csv('VAERS/2021VAERSSYMPTOMS.csv', encoding = "ISO-8859-1")

# %%
df.head(3)
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916710  01/01/2021    MO     23.0     23.0      NaN   F      NaN
# 1    916741  01/01/2021    AR     68.0     68.0      NaN   F      NaN
# 2    916742  01/01/2021    MN     29.0     29.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Acute appendicitis, onset morning of 1/1/2021 ...  NaN  ...
# 1  on dec 22 I felt some myalgias, chills, fatigu...  NaN  ...
# 2  Within 15 minutes of receiving the vaccine I b...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                                NaN
# 1  had surgery R hand for advanced arthritis 11/1...
# 2                                               None
#
#                                              HISTORY  PRIOR_VAX SPLTTYPE  \
# 0                                     Hypothyroidism        NaN      NaN
# ...

# %%
df_symp['SYMPTOM1']
is_death = df_symp['SYMPTOM1']=='Death'

# %%
vaersID = df_symp[is_death]['VAERS_ID'].values

# %%
for i in vaersID:
    vax = df_vax[df_vax.VAERS_ID.eq(i)]
    data = df[df.VAERS_ID.eq(i)]
    print(vax['VAX_MANU'].values[0], data['AGE_YRS'].values[0], data['SYMPTOM_TEXT'].values[0], data['HISTORY'].values[0])
    print ("-------------------")
# Out:
# SANOFI PASTEUR 78.0 respitory colase large T-cell lymphoma, HTN, Gout,  recieving treatment for fluide in lags
# -------------------
# MODERNA 64.0 1/1/2020: Residents was found unresponsive. Pronounced deceased at 6:02pm - SCHIZOPHRENIA, UNSPECIFIED     - ANEMIA, UNSPECIFIED  - OVERWEIGHT  - OVERACTIVE BLADDER  - ATHEROSCLEROTIC HEART DISEASE OF NATIVE CORONARY ARTERY WITHOUT ANGINA PECTORIS  - HYPOTHYROIDISM DUE TO MEDICAMENTS AND OTHER EXOGENOUS SUBSTANCES  - NICOTINE DEPENDENCE, UNSPECIFIED, UNCOMPLICATED  - CHRONIC VIRAL HEPATITIS C  - UNSPECIFIED AGE-RELATED CATARACT  - ESSENTIAL (PRIMARY) HYPERTENSION  - CHRONIC OBSTRUCTIVE PULMONARY DISEASE, UNSPECIFIED  - UNSPECIFIED CONVULSIONS  - INHALANT ABUSE, UNCOMPLICATED  - OTHER SEIZURES
# -------------------
# PFIZER\BIONTECH 65.0 Resident found unresponsive without pulse, respirations at 04:30 CPR performed, expired at 04:52 by Rescue As noted above
# -------------------
# ...

# %%
age = df['AGE_YRS']
died = df['DIED']

# %%
mapping = {'Y': 1}

died = died.fillna(0)
died = died.replace(mapping)

# %%
correlation = age.corr(died)

# %%
correlation
# Out:
# 0.6066684539833276

# %%
df_vax
# Out:
#      VAERS_ID VAX_TYPE          VAX_MANU   VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0      916710  COVID19           MODERNA       NaN               1        IM
# 1      916741  COVID19   PFIZER\BIONTECH    EH9899               1       SYR
# 2      916742  COVID19   PFIZER\BIONTECH       NaN               1        IM
# 3      916746  COVID19           MODERNA   037K20A               1        IM
# 4      916790  COVID19   PFIZER\BIONTECH       NaN               1        IM
# ..        ...      ...               ...       ...             ...       ...
# 332    926930      HEP  MERCK & CO. INC.  GSK-K2L9               1        SC
# 333    926930      MMR  MERCK & CO. INC.   S039312               1        SC
# 334    926930   VARCEL  MERCK & CO. INC.   T017684               1        SC
# 335    927189  COVID19   PFIZER\BIONTECH    EK9231               1       SYR
# 336    927260  COVID19           MODERNA   037K20A               1        IM
#
# ...
